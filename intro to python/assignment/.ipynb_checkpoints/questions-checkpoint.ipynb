# %%
#find x raised power n

x = int(input())
n = int(input())
res = pow(x,n)
print(res)
# Out:
# 2
# 2
# 4

# %%
# Arithmetic Progression
a = int(input())
b = int(input())
c = int(input())
ans = b-a
print(ans)
# Out:
# 1
# 3
# 5
# 2

# %%
# Rectangular Area
x1 = int(input())
y1 = int(input())
x2 = int(input())
y2 = int(input())
area = (x2-x1) * (y2-y1)
print(area)
# Out:
# 1
# 1
# 3
# 3
# 4
