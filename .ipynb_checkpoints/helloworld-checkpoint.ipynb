# %% [markdown]
# ### Print HelloWorld

# %%
print("HelloWorld")
# Out:
# HelloWorld

# %%
print('hello, my name is ABC')
print("Hello world")
10
# Out:
# hello, my name is ABC
# Hello world
# 10

# %% [markdown]
# ### Variables

# %%
a = 10
b = 20

a + b
# sum = a + b
# print(sum)
# Out:
# 30

# %%
abc1 = 10
ab_cl = 2
# 21ss = 2 Not Allowed
_ss = 45

# %% [markdown]
# ### assigning diffrent type of data to a variable

# %%
a = 10
a = 20
a = 'hthths'
a
# Out:
# 'hthths'

# %%
a = "abc"
print(type(a))
a = 10
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
